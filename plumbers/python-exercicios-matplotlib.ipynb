# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Gráfico de Pizza

# %%
import matplotlib.pyplot as plt

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x: 'ArrayLike', explode: 'ArrayLike | None' = None, labels: 'Sequence[str] | None' = None, colors: 'ColorType | Sequence[ColorType] | None' = None, autopct: 'str | Callable[[float], str] | None' = None, pctdistance: 'float' = 0.6, shadow: 'bool' = False, labeldistance: 'float | None' = 1.1, startangle: 'float' = 0, radius: 'float' = 1, counterclock: 'bool' = True, wedgeprops: 'dict[str, Any] | None' = None, textprops: 'dict[str, Any] | None' = None, center: 'tuple[float, float]' = (0, 0), frame: 'bool' = False, rotatelabels: 'bool' = False, *, normalize: 'bool' = True, hatch: 'str | Sequence[str] | None' = None, data=None) -> 'tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]'
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
# ...

# %%
dir(plt.pie)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
valores = [15, 30, 45, 10]
rotulos = ['Frogs', 'Hogs', 'Dogs', 'Logs']

plt.figure(figsize=(10,10))

plt.pie(valores, labels=rotulos)
plt.show()

# %%
valores = [15, 30, 45, 10]
rotulos = ['Frogs', 'Hogs', 'Dogs', 'Logs']
explode = [0, 0.1, 0, 0]
cores = ['blue', 'orange', 'green', 'red']

plt.figure(figsize=(7,7))

plt.pie(
      valores
    , labels=rotulos
    , explode=explode
    #, colors=cores
    , autopct='%.1f%%'
    , pctdistance=0.8    
    , shadow=True
    #, frame=True
    , startangle=90 # valores em graus
    , rotatelabels=True
)
plt.show()

# %% [markdown]
# ## Gráfico de Pontos

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(6,4))

# %%
help(plt.scatter)
# Out:
# Help on function scatter in module matplotlib.pyplot:
#
# scatter(x: 'float | ArrayLike', y: 'float | ArrayLike', s: 'float | ArrayLike | None' = None, c: 'ArrayLike | Sequence[ColorType] | ColorType | None' = None, marker: 'MarkerType | None' = None, cmap: 'str | Colormap | None' = None, norm: 'str | Normalize | None' = None, vmin: 'float | None' = None, vmax: 'float | None' = None, alpha: 'float | None' = None, linewidths: 'float | Sequence[float] | None' = None, *, edgecolors: "Literal['face', 'none'] | ColorType | Sequence[ColorType] | None" = None, plotnonfinite: 'bool' = False, data=None, **kwargs) -> 'PathCollection'
#     A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
#     Parameters
#     ----------
#     x, y : float or array-like, shape (n, )
#         The data positions.
#
#     s : float or array-like, shape (n, ), optional
#         The marker size in points**2 (typographic points are 1/72 in.).
# ...

# %%
x = [1.3, 2.4, 3.3, 4.0, 4.4, 5.0]
y = [63, 34, 22, 48, 18, 5]
tamanho = np.array([10, 6, 3, 8, 2, 10]) * 20
cores = ['Red', 'Green', 'Yellow', 'Yellow', 'Green', 'Red']

plt.scatter(
      x, y
    , s= tamanho
    , c= cores
    , marker="P"
    , cmap='Set1'
    , alpha=0.6
)
plt.xticks(np.arange(1.5, 5.1, 0.5))
plt.yticks(range(20,61,10))
plt.show()
# Out:
# /var/folders/32/j5chh2bs2p91hdldnvkwbx240000gn/T/ipykernel_15974/2280849423.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
x1 = np.random.rand(500)
y1 = np.random.rand(500)

plt.figure(figsize=(10,10))

plt.scatter(
    x1,
    y1,
    s=150,
    alpha=0.6 # Fica escuro onde os pontos se encontram
)
plt.plot()
# Out:
# []

# %%
# usando o vsvmax e vmin - para legenda (Para tamanhos muito diferentes)

x = [1.3, 2.4, 3.3, 4.0, 4.4, 5.0]
y = [63, 34, 22, 48, 18, 5]
#tamanho = np.array([10, 6, 3, 8, 2, 10]) * 20
tamanho = [1000, 60, 3, 800, 2, 10]
cores = ['Red', 'Green', 'Yellow', 'Yellow', 'Green', 'Red']

plt.scatter(
      x, y
    , s= tamanho
    , c= cores
    , marker="P"
    , cmap='Set1'
    , alpha=0.6
)
plt.xticks(np.arange(1.5, 5.1, 0.5))
plt.yticks(range(20,61,10))
plt.show()
# Out:
# /var/folders/32/j5chh2bs2p91hdldnvkwbx240000gn/T/ipykernel_15974/2405142132.py:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %% [markdown]
# ## Gráficos de Barra

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(x: 'float | ArrayLike', height: 'float | ArrayLike', width: 'float | ArrayLike' = 0.8, bottom: 'float | ArrayLike | None' = None, *, align: "Literal['center', 'edge']" = 'center', data=None, **kwargs) -> 'BarContainer'
#     Make a bar plot.
#
#     The bars are positioned at *x* with the given *align*\ment. Their
#     dimensions are given by *height* and *width*. The vertical baseline
#     is *bottom* (default 0).
#
#     Many parameters can take either a single value applying to all bars
#     or a sequence of values, one for each bar.
#
#     Parameters
#     ----------
#     x : float or array-like
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     height : float or array-like
#         The height(s) of the bars.
#
#         Note that if *bottom* has units (e.g. datetime), *height* should be in
# ...

# %%
x = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']
y = [10, 8, 6, 4, 2, 1]

# %%
plt.figure(figsize=(6,4))

plt.bar(
    x,
    y,
    color='mediumslateblue',
    alpha=0.8,
    edgecolor='black'
)

plt.ylabel('Usage')
plt.title('Programming Language Usage')
plt.ylim(0,11)
plt.show()
